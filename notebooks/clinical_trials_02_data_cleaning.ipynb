# %% [markdown]
# # Predictive Analysis on Clinical Trial Outcomes
#
# #### Investigator
# - [Nicholas S. McBride, PhD](https://www.linkedin.com/in/nsmcbride/)
#
# ## Section 2: Data Cleaning
#
# ##### [ClinicalTrials.gov](https://clinicaltrials.gov/) Reference Links
#
# - [API documentation](https://clinicaltrials.gov/data-api/api)
# - [Data structure](https://clinicaltrials.gov/data-api/about-api/study-data-structure)
# - [ESSIE query syntax](https://clinicaltrials.gov/find-studies/constructing-complex-search-queries)

# %%
# Imports
import numpy as np
import pandas as pd
import bz2
import pickle
from os import listdir
from time import time

# %%
# Google Colab environment
# Determine if runtime is a Google Colab enviroment
colab = 'google.colab' in str(get_ipython())

# Workspace settings
if colab:
    project_path = data_path = './'
else:
    project_path = '../'
    data_path = project_path + 'data/'

# %% [markdown]
# ### Load Data

# %%
# Load list of in scope fields
with open(project_path + 'inscope_fields.txt') as file:
    fields = file.read().splitlines()
print(f'Fields selected: {len(fields)}')

# Load API field information from pickle
field_info = pd.read_pickle(data_path + 'field_info.pkl.bz2')

# Create dicts to lookup field name from piece name and the  reverse
field_to_piece = dict(field_info[['field', 'piece']].values)
piece_to_field = dict(field_info[['piece', 'field']].values)
# Out:
# Fields selected: 115

# %%
# Find data files
file_list = listdir(data_path)

# Filter the file list
file_list = [file for file in file_list if file[0] != "." and 'json' in file]

# Use the most recent download
file_list.sort(reverse=True)
print(f'ClinicalTrials.gov API download files found: {file_list}')
filename = data_path + file_list[0]

# Load the saved API data
print(f'Loading file {filename}...')
start_time = time()
with bz2.BZ2File(filename, 'r') as file:
    studies_json = pickle.load(file)
print(f'Data loaded in {round(time() - start_time, 1)}s')
# Out:
# ClinicalTrials.gov API download files found: ['2024-05-22T142524_studies_json.pkl.bz2', '2024-05-18T204549_studies_json.pkl.bz2']
# Loading file ../data/2024-05-22T142524_studies_json.pkl.bz2...
# Data loaded in 24.5s

# %%
# Convert to a pd.DateFrame
studies = pd.json_normalize(studies_json)

# Unload the JSON from memory
del studies_json

studies.head()
# Out:
#   protocolSection.identificationModule.nctId  \
# 0                                NCT01871896
# 1                                NCT00330096
# 2                                NCT02247596
# 3                                NCT03110796
# 4                                NCT00405496
#
#   protocolSection.identificationModule.organization.fullName  \
# 0            University of California, San Francisco
# 1                  Société des Produits Nestlé (SPN)
# 2                            Khoo Teck Puat Hospital
# 3                                  Laboratoires URGO
# 4                          Sirion Therapeutics, Inc.
#
#   protocolSection.identificationModule.organization.class  \
# 0                                              OTHER
# 1                                           INDUSTRY
# 2                                              OTHER
# 3                                           INDUSTRY
# 4                                           INDUSTRY
#
#   protocolSection.statusModule.statusVerifiedDate  \
# 0                                         2023-07
# 1                                         2013-10
# 2                                         2014-09
# 3                                         2019-01
# 4                                         2006-11
#
#   protocolSection.statusModule.overallStatus  \
# 0                                  COMPLETED
# 1                                  COMPLETED
# 2                                  COMPLETED
# 3                                    UNKNOWN
# 4                                  COMPLETED
#
#   protocolSection.statusModule.expandedAccessInfo.hasExpandedAccess  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   protocolSection.statusModule.startDateStruct.date  \
# 0                                           2014-01
# 1                                           2006-03
# 2                                           2009-07
# 3                                        2017-07-31
# 4                                           2000-03
#
#   protocolSection.statusModule.primaryCompletionDateStruct.date  \
# 0                                            2022-06
# 1                                                NaN
# 2                                            2012-10
# 3                                            2020-01
# 4                                                NaN
#
#   protocolSection.statusModule.primaryCompletionDateStruct.type  \
# 0                                             ACTUAL
# 1                                                NaN
# 2                                             ACTUAL
# 3                                          ESTIMATED
# 4                                                NaN
#
#   protocolSection.statusModule.completionDateStruct.date  ...  \
# 0                                            2022-06      ...
# 1                                            2009-04      ...
# 2                                            2012-10      ...
# 3                                            2020-01      ...
# 4                                            2001-04      ...
#
#   protocolSection.identificationModule.orgStudyIdInfo.type  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   protocolSection.referencesModule.availIpds  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   protocolSection.statusModule.expandedAccessInfo.statusForNctId  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   protocolSection.oversightModule.isUnapprovedDevice  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   protocolSection.designModule.expandedAccessTypes.intermediate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   protocolSection.designModule.expandedAccessTypes.treatment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   documentSection.largeDocumentModule.noSap  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   protocolSection.designModule.expandedAccessTypes.individual  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   protocolSection.oversightModule.fdaaa801Violation  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   protocolSection.oversightModule.isPpsd
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
# [5 rows x 73 columns]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Unpack Lists of Dictionaries

# %%
# Functions for data cleaning

def find_list_columns(df):
    """
    Iterates over the columns of a pd.DataFrame to determine is any of the values are a list type.
    Returns a list of the names of columns that contain lists.
    """
    return list(df.columns[df.map(lambda value: isinstance(value, list)).any()])

def unpack_dict_list(series, field_to_piece=field_to_piece):
    """
    Unpack lists of dictionary obects into seperate columns for each piece
    """

    df = pd.DataFrame(index=series.index)
    
    for row, dict_list in enumerate(series):
        row_index = series.index[row]

        # Check for NaN
        if dict_list != dict_list:
            continue

        # Check if it's not a list of dictionaries, return the original object if it is not
        if not isinstance(dict_list[0], dict):

            # Create the column with all NoneType values if it doesn't exist
            if series.name not in df.columns:
                df[series.name] = None
            
            df.at[row_index, series.name] = dict_list
            continue
        
        for dictionary in dict_list:
            for key, value in dictionary.items():

                # Check for double-nested dict
                if isinstance(value, dict):

                    # Create the column with NoneType values if it doesn't exist
                    if key not in df.columns:
                        df[key] = None
                    
                    df.at[row_index, key] = value
                    continue
                
                piece = field_to_piece[series.name + '.' + key]
                
                if piece in df.columns:

                    df_element = df.at[row_index, piece]

                    # Check if there is a NaN in there, replace if so
                    if df_element != df_element or df_element is None:
                        df.at[row_index, piece] = [value]
                        
                    elif isinstance(df_element, list):
                        df.at[row_index, piece].append(value)
                    else: # This should not run
                        print('Found element that is not a list.')
                        df.at[row_index, piece] = [df_element, value]
                        
                else:
                    # Create the column with all None
                    df[piece] = None

                    # Set the value in the specified element
                    df.at[row_index, piece] = [value]
    return df

# %%
# Determine which columns contain embedded lists to be unpacked
list_cols = find_list_columns(studies)
list_cols
# Out:
# ['protocolSection.conditionsModule.conditions',
#  'protocolSection.conditionsModule.keywords',
#  'protocolSection.designModule.phases',
#  'protocolSection.armsInterventionsModule.armGroups',
#  'protocolSection.armsInterventionsModule.interventions',
#  'protocolSection.outcomesModule.primaryOutcomes',
#  'protocolSection.outcomesModule.secondaryOutcomes',
#  'protocolSection.eligibilityModule.stdAges',
#  'protocolSection.contactsLocationsModule.overallOfficials',
#  'protocolSection.contactsLocationsModule.locations',
#  'protocolSection.referencesModule.references',
#  'protocolSection.sponsorCollaboratorsModule.collaborators',
#  'protocolSection.designModule.designInfo.maskingInfo.whoMasked',
#  'protocolSection.contactsLocationsModule.centralContacts',
#  'protocolSection.identificationModule.secondaryIdInfos',
#  'protocolSection.ipdSharingStatementModule.infoTypes',
#  'protocolSection.outcomesModule.otherOutcomes',
#  'protocolSection.referencesModule.availIpds']

# %%
# Unpack the dictionaries embedded in lists
for col in list_cols:
    print(f'Unpacking dictionary lists in {col}...')
    studies = pd.merge(studies.drop(columns=col), unpack_dict_list(studies[col], field_to_piece), left_index=True, right_index=True)

studies.head()
# Out:
# Unpacking dictionary lists in protocolSection.conditionsModule.conditions...
# Unpacking dictionary lists in protocolSection.conditionsModule.keywords...
# Unpacking dictionary lists in protocolSection.designModule.phases...
# Unpacking dictionary lists in protocolSection.armsInterventionsModule.armGroups...
# Unpacking dictionary lists in protocolSection.armsInterventionsModule.interventions...
# Unpacking dictionary lists in protocolSection.outcomesModule.primaryOutcomes...
# Unpacking dictionary lists in protocolSection.outcomesModule.secondaryOutcomes...
# Unpacking dictionary lists in protocolSection.eligibilityModule.stdAges...
# Unpacking dictionary lists in protocolSection.contactsLocationsModule.overallOfficials...
# Unpacking dictionary lists in protocolSection.contactsLocationsModule.locations...
# Unpacking dictionary lists in protocolSection.referencesModule.references...
# Unpacking dictionary lists in protocolSection.sponsorCollaboratorsModule.collaborators...
# Unpacking dictionary lists in protocolSection.designModule.designInfo.maskingInfo.whoMasked...
# Unpacking dictionary lists in protocolSection.contactsLocationsModule.centralContacts...
# Unpacking dictionary lists in protocolSection.identificationModule.secondaryIdInfos...
# Unpacking dictionary lists in protocolSection.ipdSharingStatementModule.infoTypes...
# Unpacking dictionary lists in protocolSection.outcomesModule.otherOutcomes...
# Unpacking dictionary lists in protocolSection.referencesModule.availIpds...
#   protocolSection.identificationModule.nctId  \
# 0                                NCT01871896
# 1                                NCT00330096
# 2                                NCT02247596
# 3                                NCT03110796
# 4                                NCT00405496
#
#   protocolSection.identificationModule.organization.fullName  \
# 0            University of California, San Francisco
# 1                  Société des Produits Nestlé (SPN)
# 2                            Khoo Teck Puat Hospital
# 3                                  Laboratoires URGO
# 4                          Sirion Therapeutics, Inc.
#
#   protocolSection.identificationModule.organization.class  \
# 0                                              OTHER
# 1                                           INDUSTRY
# 2                                              OTHER
# 3                                           INDUSTRY
# 4                                           INDUSTRY
#
#   protocolSection.statusModule.statusVerifiedDate  \
# 0                                         2023-07
# 1                                         2013-10
# 2                                         2014-09
# 3                                         2019-01
# 4                                         2006-11
#
#   protocolSection.statusModule.overallStatus  \
# 0                                  COMPLETED
# 1                                  COMPLETED
# 2                                  COMPLETED
# 3                                    UNKNOWN
# 4                                  COMPLETED
#
#   protocolSection.statusModule.expandedAccessInfo.hasExpandedAccess  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   protocolSection.statusModule.startDateStruct.date  \
# 0                                           2014-01
# 1                                           2006-03
# 2                                           2009-07
# 3                                        2017-07-31
# 4                                           2000-03
#
#   protocolSection.statusModule.primaryCompletionDateStruct.date  \
# 0                                            2022-06
# 1                                                NaN
# 2                                            2012-10
# 3                                            2020-01
# 4                                                NaN
#
#   protocolSection.statusModule.primaryCompletionDateStruct.type  \
# 0                                             ACTUAL
# 1                                                NaN
# 2                                             ACTUAL
# 3                                          ESTIMATED
# 4                                                NaN
#
#   protocolSection.statusModule.completionDateStruct.date  ...  \
# 0                                            2022-06      ...
# 1                                            2009-04      ...
# 2                                            2012-10      ...
# 3                                            2020-01      ...
# 4                                            2001-04      ...
#
#                                     CollaboratorName CollaboratorClass  \
# 0                                               None              None
# 1  [Institut National de Recherche pour l'Agricul...  [OTHER, UNKNOWN]
# 2  [National Medical Research Council (NMRC), Sin...       [OTHER_GOV]
# 3                                               None              None
# 4                                               None              None
#
#   protocolSection.designModule.designInfo.maskingInfo.whoMasked  \
# 0                                               None
# 1                                               None
# 2                        [PARTICIPANT, INVESTIGATOR]
# 3                  [INVESTIGATOR, OUTCOMES_ASSESSOR]
# 4                                               None
#
#                          CentralContactName  CentralContactRole  \
# 0                                      None                None
# 1                                      None                None
# 2                                      None                None
# 3  [Anne Sauvadet, PhD, Olivier Tacca, PhD]  [CONTACT, CONTACT]
# 4                                      None                None
#
#   SecondaryIdType protocolSection.ipdSharingStatementModule.infoTypes  \
# 0            None                                               None
# 1            None                                               None
# 2            None                                               None
# 3            None                                               None
# 4            None                                               None
#
#   OtherOutcomeMeasure OtherOutcomeTimeFrame AvailIPDType
# 0                None                  None         None
# 1                None                  None         None
# 2                None                  None         None
# 3                None                  None         None
# 4                None                  None         None
#
# [5 rows x 86 columns]

# %% [markdown]
# #### Rename Columns

# %% [markdown]
# Rename the columns using the unique piece name from documentation to improve readability and typability.

# %%
# Rename columns using piece names for better readability
studies.rename(columns=field_to_piece, inplace=True)
studies.columns
# Out:
# Index(['NCTId', 'OrgFullName', 'OrgClass', 'StatusVerifiedDate',
#        'OverallStatus', 'HasExpandedAccess', 'StartDate',
#        'PrimaryCompletionDate', 'PrimaryCompletionDateType', 'CompletionDate',
#        'CompletionDateType', 'StudyFirstSubmitDate', 'StudyFirstSubmitQCDate',
#        'LastUpdateSubmitDate', 'ResponsiblePartyType', 'LeadSponsorName',
#        'LeadSponsorClass', 'OversightHasDMC', 'StudyType', 'DesignAllocation',
#        'DesignInterventionModel', 'DesignPrimaryPurpose', 'DesignMasking',
#        'EnrollmentCount', 'EnrollmentType', 'HealthyVolunteers', 'Sex',
#        'MinimumAge', 'MaximumAge', 'ResponsiblePartyInvestigatorTitle',
#        'ResponsiblePartyInvestigatorAffiliation', 'StartDateType',
#        'IsFDARegulatedDrug', 'IsFDARegulatedDevice', 'IPDSharing',
#        'DispFirstSubmitDate', 'DispFirstSubmitQCDate', 'WhyStopped',
#        'PatientRegistry', 'TargetDuration', 'DesignObservationalModel',
#        'DesignTimePerspective', 'SamplingMethod', 'BioSpecRetention',
#        'IsUSExport', 'GenderBased', 'OrgStudyIdType',
#        'ExpandedAccessStatusForNCTId', 'IsUnapprovedDevice',
#        'ExpAccTypeIntermediate', 'ExpAccTypeTreatment', 'LargeDocNoSAP',
#        'ExpAccTypeIndividual', 'FDAAA801Violation', 'IsPPSD', 'Condition',
#        'Keyword', 'Phase', 'ArmGroupLabel', 'ArmGroupType',
#        'ArmGroupInterventionName', 'InterventionType', 'InterventionName',
#        'InterventionArmGroupLabel', 'PrimaryOutcomeMeasure',
#        'PrimaryOutcomeTimeFrame', 'SecondaryOutcomeMeasure',
#        'SecondaryOutcomeTimeFrame', 'StdAge', 'OverallOfficialName',
#        'OverallOfficialAffiliation', 'OverallOfficialRole', 'LocationState',
#        'LocationCountry', 'LocationStatus', 'ReferenceType',
#        'CollaboratorName', 'CollaboratorClass', 'DesignWhoMasked',
#        'CentralContactName', 'CentralContactRole', 'SecondaryIdType',
#        'IPDSharingInfoType', 'OtherOutcomeMeasure', 'OtherOutcomeTimeFrame',
#        'AvailIPDType'],
#       dtype='object')

# %%
# Redetermine which columns contain embedded lists after unpacking dictionaries
list_cols = find_list_columns(studies)
list_cols
# Out:
# ['Condition',
#  'Keyword',
#  'Phase',
#  'ArmGroupLabel',
#  'ArmGroupType',
#  'ArmGroupInterventionName',
#  'InterventionType',
#  'InterventionName',
#  'InterventionArmGroupLabel',
#  'PrimaryOutcomeMeasure',
#  'PrimaryOutcomeTimeFrame',
#  'SecondaryOutcomeMeasure',
#  'SecondaryOutcomeTimeFrame',
#  'StdAge',
#  'OverallOfficialName',
#  'OverallOfficialAffiliation',
#  'OverallOfficialRole',
#  'LocationState',
#  'LocationCountry',
#  'LocationStatus',
#  'ReferenceType',
#  'CollaboratorName',
#  'CollaboratorClass',
#  'DesignWhoMasked',
#  'CentralContactName',
#  'CentralContactRole',
#  'SecondaryIdType',
#  'IPDSharingInfoType',
#  'OtherOutcomeMeasure',
#  'OtherOutcomeTimeFrame',
#  'AvailIPDType']

# %% [markdown]
# #### Convert Data Types

# %% [markdown]
# Take a look at columns that are listed as boolean data types to make sure there are no nested fields or all one value.

# %%
# Investigate 'boolean' fields
bool_pieces = field_info.loc[(field_info['type'] == 'BOOLEAN') & (field_info['field'].isin(fields)), 'piece']
studies[studies.columns[studies.columns.isin(bool_pieces)]].describe().T
# Out:
#                          count unique    top    freq
# HasExpandedAccess       378669      2  False  378058
# OversightHasDMC         311704      2  False  202307
# HealthyVolunteers       374752      2  False  269016
# IsFDARegulatedDrug      166824      2  False  140939
# IsFDARegulatedDevice    166797      2  False  157644
# PatientRegistry          60846      2  False   53749
# IsUSExport               23821      2  False   16658
# GenderBased               8720      1   True    8720
# IsUnapprovedDevice        2083      1   True    2083
# ExpAccTypeIntermediate     177      1   True     177
# ExpAccTypeTreatment        182      1   True     182
# LargeDocNoSAP              492      1   True     492
# ExpAccTypeIndividual       254      1   True     254
# FDAAA801Violation            5      1   True       5
# IsPPSD                       8      1   True       8

# %% [markdown]
# Each of the columns contains either True/False/NaN or True/NaN without any False values. None are uniformly filled with the same value. We will have to be careful in converting the data types as `np.nan` values are converted to `True` boolean values by default. We will convert them to a `category`.

# %%
bool(np.nan)
# Out:
# True

# %%
# Assign correct data types based on API documentation
field_info['type'].unique()
# Out:
# array(['ENUM', 'STRING', 'DATE', 'INTEGER', 'NUMBER', 'BOOLEAN'],
#       dtype=object)

# %%
# Function for data type parsing
def parse_age(age_string):
    """
    Function to parse the age values given by the ClinicalTrials.gov API.
    These values are given in the formate of a 'number time-unit'
    """
    if isinstance(age_string, float):
        return age_string
        
    age = age_string.split()
    
    if age[1].lower().startswith('year'):
        return np.float32(age[0])
    elif age[1].lower().startswith('month'):
        return np.float32(float(age[0]) / 12)
    elif age[1].lower().startswith('week'):
        return np.float32(float(age[0]) / 52.1429)
    elif age[1].lower().startswith('day'):
        return np.float32(float(age[0]) / 365.25)
    elif age[1].lower().startswith('hour'):
        return np.float32(float(age[0]) / 8766)
    elif age[1].lower().startswith('minute'):
        return np.float32(float(age[0]) / 525960)
        
    else:
        raise Exception(f'Unexpected unit {age[1]}')

# %%
studies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383135 entries, 0 to 383134
# Data columns (total 86 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   NCTId                                    383135 non-null  object
#  1   OrgFullName                              383135 non-null  object
#  2   OrgClass                                 383135 non-null  object
#  3   StatusVerifiedDate                       383135 non-null  object
#  4   OverallStatus                            383135 non-null  object
#  5   HasExpandedAccess                        378669 non-null  object
#  6   StartDate                                378873 non-null  object
#  7   PrimaryCompletionDate                    362437 non-null  object
#  8   PrimaryCompletionDateType                362374 non-null  object
#  9   CompletionDate                           367623 non-null  object
#  10  CompletionDateType                       360842 non-null  object
#  11  StudyFirstSubmitDate                     383135 non-null  object
#  12  StudyFirstSubmitQCDate                   383135 non-null  object
#  13  LastUpdateSubmitDate                     383135 non-null  object
#  14  ResponsiblePartyType                     339884 non-null  object
#  15  LeadSponsorName                          383135 non-null  object
#  16  LeadSponsorClass                         383135 non-null  object
#  17  OversightHasDMC                          311704 non-null  object
#  18  StudyType                                383135 non-null  object
#  19  DesignAllocation                         292248 non-null  object
#  20  DesignInterventionModel                  291361 non-null  object
#  21  DesignPrimaryPurpose                     290850 non-null  object
#  22  DesignMasking                            292702 non-null  object
#  23  EnrollmentCount                          377102 non-null  float64
#  24  EnrollmentType                           367054 non-null  object
#  25  HealthyVolunteers                        374752 non-null  object
#  26  Sex                                      382709 non-null  object
#  27  MinimumAge                               356813 non-null  object
#  28  MaximumAge                               206927 non-null  object
#  29  ResponsiblePartyInvestigatorTitle        145396 non-null  object
#  30  ResponsiblePartyInvestigatorAffiliation  145404 non-null  object
#  31  StartDateType                            198996 non-null  object
#  32  IsFDARegulatedDrug                       166824 non-null  object
#  33  IsFDARegulatedDevice                     166797 non-null  object
#  34  IPDSharing                               153935 non-null  object
#  35  DispFirstSubmitDate                      8749 non-null    object
#  36  DispFirstSubmitQCDate                    8128 non-null    object
#  37  WhyStopped                               38835 non-null   object
#  38  PatientRegistry                          60846 non-null   object
#  39  TargetDuration                           7097 non-null    object
#  40  DesignObservationalModel                 78431 non-null   object
#  41  DesignTimePerspective                    81329 non-null   object
#  42  SamplingMethod                           80124 non-null   object
#  43  BioSpecRetention                         16088 non-null   object
#  44  IsUSExport                               23821 non-null   object
#  45  GenderBased                              8720 non-null    object
#  46  OrgStudyIdType                           3984 non-null    object
#  47  ExpandedAccessStatusForNCTId             495 non-null     object
#  48  IsUnapprovedDevice                       2083 non-null    object
#  49  ExpAccTypeIntermediate                   177 non-null     object
#  50  ExpAccTypeTreatment                      182 non-null     object
#  51  LargeDocNoSAP                            492 non-null     object
#  52  ExpAccTypeIndividual                     254 non-null     object
#  53  FDAAA801Violation                        5 non-null       object
#  54  IsPPSD                                   8 non-null       object
#  55  Condition                                383103 non-null  object
#  56  Keyword                                  247079 non-null  object
#  57  Phase                                    297894 non-null  object
#  58  ArmGroupLabel                            328058 non-null  object
#  59  ArmGroupType                             274325 non-null  object
#  60  ArmGroupInterventionName                 309569 non-null  object
#  61  InterventionType                         345399 non-null  object
#  62  InterventionName                         345299 non-null  object
#  63  InterventionArmGroupLabel                309636 non-null  object
#  64  PrimaryOutcomeMeasure                    366635 non-null  object
#  65  PrimaryOutcomeTimeFrame                  353465 non-null  object
#  66  SecondaryOutcomeMeasure                  274203 non-null  object
#  67  SecondaryOutcomeTimeFrame                263759 non-null  object
#  68  StdAge                                   383135 non-null  object
#  69  OverallOfficialName                      296848 non-null  object
#  70  OverallOfficialAffiliation               295362 non-null  object
#  71  OverallOfficialRole                      296203 non-null  object
#  72  LocationState                            222265 non-null  object
#  73  LocationCountry                          343255 non-null  object
#  74  LocationStatus                           38202 non-null   object
#  75  ReferenceType                            142346 non-null  object
#  76  CollaboratorName                         121537 non-null  object
#  77  CollaboratorClass                        121537 non-null  object
#  78  DesignWhoMasked                          126037 non-null  object
#  79  CentralContactName                       47566 non-null   object
#  80  CentralContactRole                       47566 non-null   object
#  81  SecondaryIdType                          61084 non-null   object
#  82  IPDSharingInfoType                       12253 non-null   object
#  83  OtherOutcomeMeasure                      27111 non-null   object
#  84  OtherOutcomeTimeFrame                    27091 non-null   object
#  85  AvailIPDType                             2488 non-null    object
# dtypes: float64(1), object(85)
# memory usage: 251.4+ MB

# %%
# Convert data types
for col in studies.drop(columns=list_cols).columns:
        
    doc_dtype = field_info.loc[field_info["piece"] == col, "type"].values[0]
    df_dtype = studies[col].dtype

    # Handle incorrectly labeled types
    if col in ['MinimumAge', 'MaximumAge', 'TargetDuration']:
        print(f'Converting {col} ({df_dtype}) documented as {doc_dtype} to float32 in years')
        studies[col] = studies[col].map(parse_age).astype(np.float32)
        
    elif doc_dtype == 'DATE':
        print(f'Converting {col} ({df_dtype}) documented as {doc_dtype} to datetime')
        studies[col] = pd.to_datetime(studies[col], format='ISO8601')
        
    elif doc_dtype in ['BOOLEAN', 'ENUM']:
        print(f'Converting {col} ({df_dtype}) documented as {doc_dtype} to category')
        studies[col] = studies[col].astype('category')
        
    elif doc_dtype in ['INTEGER', 'NUMBER']:
            print(f'Converting {col} ({df_dtype}) documented as {doc_dtype} to float32 to preserve NA values')
            studies[col] = studies[col].astype(np.float32)
# Out:
# Converting OrgClass (object) documented as ENUM to category
# Converting StatusVerifiedDate (object) documented as DATE to datetime
# Converting OverallStatus (object) documented as ENUM to category
# Converting HasExpandedAccess (object) documented as BOOLEAN to category
# Converting StartDate (object) documented as DATE to datetime
# Converting PrimaryCompletionDate (object) documented as DATE to datetime
# Converting PrimaryCompletionDateType (object) documented as ENUM to category
# Converting CompletionDate (object) documented as DATE to datetime
# Converting CompletionDateType (object) documented as ENUM to category
# Converting StudyFirstSubmitDate (object) documented as DATE to datetime
# Converting StudyFirstSubmitQCDate (object) documented as DATE to datetime
# Converting LastUpdateSubmitDate (object) documented as DATE to datetime
# Converting ResponsiblePartyType (object) documented as ENUM to category
# Converting LeadSponsorClass (object) documented as ENUM to category
# Converting OversightHasDMC (object) documented as BOOLEAN to category
# Converting StudyType (object) documented as ENUM to category
# Converting DesignAllocation (object) documented as ENUM to category
# Converting DesignInterventionModel (object) documented as ENUM to category
# Converting DesignPrimaryPurpose (object) documented as ENUM to category
# Converting DesignMasking (object) documented as ENUM to category
# Converting EnrollmentCount (float64) documented as INTEGER to float32 to preserve NA values
# Converting EnrollmentType (object) documented as ENUM to category
# Converting HealthyVolunteers (object) documented as BOOLEAN to category
# Converting Sex (object) documented as ENUM to category
# Converting MinimumAge (object) documented as NUMBER to float32 in years
# Converting MaximumAge (object) documented as NUMBER to float32 in years
# Converting StartDateType (object) documented as ENUM to category
# Converting IsFDARegulatedDrug (object) documented as BOOLEAN to category
# Converting IsFDARegulatedDevice (object) documented as BOOLEAN to category
# Converting IPDSharing (object) documented as ENUM to category
# Converting DispFirstSubmitDate (object) documented as DATE to datetime
# Converting DispFirstSubmitQCDate (object) documented as DATE to datetime
# Converting PatientRegistry (object) documented as BOOLEAN to category
# Converting TargetDuration (object) documented as NUMBER to float32 in years
# Converting DesignObservationalModel (object) documented as ENUM to category
# Converting DesignTimePerspective (object) documented as ENUM to category
# Converting SamplingMethod (object) documented as ENUM to category
# Converting BioSpecRetention (object) documented as ENUM to category
# Converting IsUSExport (object) documented as BOOLEAN to category
# Converting GenderBased (object) documented as BOOLEAN to category
# Converting OrgStudyIdType (object) documented as ENUM to category
# Converting ExpandedAccessStatusForNCTId (object) documented as ENUM to category
# Converting IsUnapprovedDevice (object) documented as BOOLEAN to category
# Converting ExpAccTypeIntermediate (object) documented as BOOLEAN to category
# Converting ExpAccTypeTreatment (object) documented as BOOLEAN to category
# Converting LargeDocNoSAP (object) documented as BOOLEAN to category
# Converting ExpAccTypeIndividual (object) documented as BOOLEAN to category
# Converting FDAAA801Violation (object) documented as BOOLEAN to category
# Converting IsPPSD (object) documented as BOOLEAN to category

# %%
studies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383135 entries, 0 to 383134
# Data columns (total 86 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   NCTId                                    383135 non-null  object
#  1   OrgFullName                              383135 non-null  object
#  2   OrgClass                                 383135 non-null  category
#  3   StatusVerifiedDate                       383135 non-null  datetime64[ns]
#  4   OverallStatus                            383135 non-null  category
#  5   HasExpandedAccess                        378669 non-null  category
#  6   StartDate                                378873 non-null  datetime64[ns]
#  7   PrimaryCompletionDate                    362437 non-null  datetime64[ns]
#  8   PrimaryCompletionDateType                362374 non-null  category
#  9   CompletionDate                           367623 non-null  datetime64[ns]
#  10  CompletionDateType                       360842 non-null  category
#  11  StudyFirstSubmitDate                     383135 non-null  datetime64[ns]
#  12  StudyFirstSubmitQCDate                   383135 non-null  datetime64[ns]
#  13  LastUpdateSubmitDate                     383135 non-null  datetime64[ns]
#  14  ResponsiblePartyType                     339884 non-null  category
#  15  LeadSponsorName                          383135 non-null  object
#  16  LeadSponsorClass                         383135 non-null  category
#  17  OversightHasDMC                          311704 non-null  category
#  18  StudyType                                383135 non-null  category
#  19  DesignAllocation                         292248 non-null  category
#  20  DesignInterventionModel                  291361 non-null  category
#  21  DesignPrimaryPurpose                     290850 non-null  category
#  22  DesignMasking                            292702 non-null  category
#  23  EnrollmentCount                          377102 non-null  float32
#  24  EnrollmentType                           367054 non-null  category
#  25  HealthyVolunteers                        374752 non-null  category
#  26  Sex                                      382709 non-null  category
#  27  MinimumAge                               356813 non-null  float32
#  28  MaximumAge                               206927 non-null  float32
#  29  ResponsiblePartyInvestigatorTitle        145396 non-null  object
#  30  ResponsiblePartyInvestigatorAffiliation  145404 non-null  object
#  31  StartDateType                            198996 non-null  category
#  32  IsFDARegulatedDrug                       166824 non-null  category
#  33  IsFDARegulatedDevice                     166797 non-null  category
#  34  IPDSharing                               153935 non-null  category
#  35  DispFirstSubmitDate                      8749 non-null    datetime64[ns]
#  36  DispFirstSubmitQCDate                    8128 non-null    datetime64[ns]
#  37  WhyStopped                               38835 non-null   object
#  38  PatientRegistry                          60846 non-null   category
#  39  TargetDuration                           7097 non-null    float32
#  40  DesignObservationalModel                 78431 non-null   category
#  41  DesignTimePerspective                    81329 non-null   category
#  42  SamplingMethod                           80124 non-null   category
#  43  BioSpecRetention                         16088 non-null   category
#  44  IsUSExport                               23821 non-null   category
#  45  GenderBased                              8720 non-null    category
#  46  OrgStudyIdType                           3984 non-null    category
#  47  ExpandedAccessStatusForNCTId             495 non-null     category
#  48  IsUnapprovedDevice                       2083 non-null    category
#  49  ExpAccTypeIntermediate                   177 non-null     category
#  50  ExpAccTypeTreatment                      182 non-null     category
#  51  LargeDocNoSAP                            492 non-null     category
#  52  ExpAccTypeIndividual                     254 non-null     category
#  53  FDAAA801Violation                        5 non-null       category
#  54  IsPPSD                                   8 non-null       category
#  55  Condition                                383103 non-null  object
#  56  Keyword                                  247079 non-null  object
#  57  Phase                                    297894 non-null  object
#  58  ArmGroupLabel                            328058 non-null  object
#  59  ArmGroupType                             274325 non-null  object
#  60  ArmGroupInterventionName                 309569 non-null  object
#  61  InterventionType                         345399 non-null  object
#  62  InterventionName                         345299 non-null  object
#  63  InterventionArmGroupLabel                309636 non-null  object
#  64  PrimaryOutcomeMeasure                    366635 non-null  object
#  65  PrimaryOutcomeTimeFrame                  353465 non-null  object
#  66  SecondaryOutcomeMeasure                  274203 non-null  object
#  67  SecondaryOutcomeTimeFrame                263759 non-null  object
#  68  StdAge                                   383135 non-null  object
#  69  OverallOfficialName                      296848 non-null  object
#  70  OverallOfficialAffiliation               295362 non-null  object
#  71  OverallOfficialRole                      296203 non-null  object
#  72  LocationState                            222265 non-null  object
#  73  LocationCountry                          343255 non-null  object
#  74  LocationStatus                           38202 non-null   object
#  75  ReferenceType                            142346 non-null  object
#  76  CollaboratorName                         121537 non-null  object
#  77  CollaboratorClass                        121537 non-null  object
#  78  DesignWhoMasked                          126037 non-null  object
#  79  CentralContactName                       47566 non-null   object
#  80  CentralContactRole                       47566 non-null   object
#  81  SecondaryIdType                          61084 non-null   object
#  82  IPDSharingInfoType                       12253 non-null   object
#  83  OtherOutcomeMeasure                      27111 non-null   object
#  84  OtherOutcomeTimeFrame                    27091 non-null   object
#  85  AvailIPDType                             2488 non-null    object
# dtypes: category(36), datetime64[ns](9), float32(4), object(37)
# memory usage: 153.5+ MB

# %% [markdown]
# ### Save DataFrame to File

# %%
# Pickle the DataFrame
studies_df_filename = data_path + 'studies_df.pkl.bz2'
studies.to_pickle(studies_df_filename, compression='bz2')
