# %% [markdown]
# # Predictive Analysis on Clinical Trial Outcomes
#
# #### Investigator
# - [Nicholas S. McBride, PhD](https://www.linkedin.com/in/nsmcbride/)
#
# ## Project Objective
# This project aims to develop predictive models to analyze clinical trial outcomes based on the study design and implementation details available before any results are published. Leveraging data from [ClinicalTrials.gov](https://clinicaltrials.gov/), the goal is to forecast the trajectory of clinical trials, which is invaluable in the Biotechnology industry for risk assessment, resource allocation, and strategic decision-making.
#
# ## Section 1: Data Collection
#
# ### Data Sources
# Data is sourced through the [ClinicalTrials.gov API](https://clinicaltrials.gov/data-api/api), which provides a comprehensive database of clinical studies. The information structure and query syntax used in this project are guided by the [API documentation](https://clinicaltrials.gov/data-api/api) and [ESSIE query syntax](https://clinicaltrials.gov/find-studies/constructing-complex-search-queries), which was [developed specifically for the ClinicalTrials.gov project at the NLM](https://doi.org/10.1197/jamia.M2233) for in silico biomedical literature research.
#
# #### [ClinicalTrials.gov](https://clinicaltrials.gov/) Reference Links
#
# - [API documentation](https://clinicaltrials.gov/data-api/api)
# - [Data structure](https://clinicaltrials.gov/data-api/about-api/study-data-structure)
# - [ESSIE query syntax](https://clinicaltrials.gov/find-studies/constructing-complex-search-queries)
#
# ### Inclusion Criteria
# The scope is confined to clinical studies categorized under specific recruitment and expanded access statuses. Clincial studies with overall status indicating a terminal success or failure were selected. Studies with overall status indicating active or in recruitment status were excluded.
#
# #### [Study Overall Status Definitions](https://clinicaltrials.gov/study-basics/glossary)
#
# | Recruitment status | Description |
# |-|-|
# | Not yet recruiting | The study has not started recruiting participants. |
# | Recruiting | The study is currently recruiting participants. |
# | Enrolling by invitation | The study is selecting its participants from a population decided on by the researchers in advance. These studies are not open to everyone who meets the eligibility criteria but only to people in that particular population, who are specifically invited to participate. |
# | Active, not recruiting | The study is ongoing, and participants are receiving an intervention or being examined, but potential participants are not currently being recruited or enrolled. |
# | Suspended | The study has stopped early but may start again. |
# | Terminated | The study has stopped early and will not start again. Participants are no longer being examined or treated. |
# | Completed | The study has ended normally, and participants are no longer being examined or treated (that is, the last participant's last visit has occurred). |
# | Withdrawn | The study stopped early, before enrolling its first participant. |
# | Unknown | A study on ClinicalTrials.gov whose last known status was recruiting; not yet recruiting; or active, not recruiting but that has passed its completion date, and the status has not been last verified within the past 2 years. |
#
# | Expanded access status | Description |
# |-|-|
# | Available | Expanded access is currently available for this investigational treatment, and patients who are not participants in the clinical study may be able to gain access to the drug, biologic, or medical device being studied. |
# | No longer available | Expanded access was available for this intervention previously but is not currently available and will not be available in the future. |
# | Temporarily not available| Expanded access is not currently available for this intervention but is expected to be available in the future. |
# | Approved for marketing | The intervention has been approved by the U.S. Food and Drug Administration for use by the public. |
#
# Based in this information. The scope was limited to studies with overall statuses:
# - Suspended
# - Terminated
# - Completed
# - Withdrawn
# - Unknown
# - Available
# - No longer available
# - Temporarily not available
# - Approved for marketing
#
# Examination of the API data revealed an additional undocumented status 'Withheld' encompassing 880 studies in the ClinicalTrials.gov database. Withheld studies contained little data and most information was redacted. These studies were excluded due to insufficient data. Further documentation reveals that "Withheld studies are a special case where a FDA-regulated device product is not yet approved or cleared by U.S. FDA".

# %% [markdown]
# ### Imports and Functions

# %%
# Imports
import requests
import pandas as pd
from datetime import date, datetime
import pickle
import bz2

# %%
# Google Colab environment
# Determine if runtime is a Google Colab enviroment
colab = 'google.colab' in str(get_ipython())

# Workspace settings
if colab:
    project_path = data_path = './'
else:
    project_path = '../'
    data_path = project_path + 'data/'

# %% [markdown]
# Here we define 2 functions for interacting with the [ClincalTrials.gov API](https://clinicaltrials.gov/data-api/api). Note that at the time of this projects completion in May, 2024. v2 of the API had been introduced two months prior and v1 of the API was in the process of being decommissioned with intermittent outages. As such, existing wrappers interacting with v1 of the API were unreliable and the following functions were written from scratch.

# %%
# Functions
def count_studies(url, parameters={'countTotal': 'true'}):
    """
    Submits an API requests and returns only the total count of studies found matching the supplied parameters.
    """

    # Add 'countTotal': 'true' and to parameters
    parameters['countTotal'] = 'true'

    # Send request
    response = requests.get(url, params=parameters)
    response.raise_for_status()
    
    return response.json()['totalCount']

def request_all_studies(url, parameters={'countTotal': 'true'}):
    """
    Submits successive API requests until all pages have been returned and combines the output into a list of studies.
    """

    # Add 'countTotal': 'true' and to parameters
    parameters['countTotal'] = 'true'

    # Initialize variables
    studies = []
    token = True
    
    while token:
        
        response = requests.get(url, params=parameters)
        response.raise_for_status()
        if 'totalCount' in response.json():
            total_count = response.json()['totalCount']

        # Note: `reponse.json()` here is converting our JSON to a python dict.
        # This will overwrite any duplicate key values, which are possible in JSON, but not in a dict.
        # For the purpose of this analysis, we will treat the presence of the values as boolean, not as quantitative variables.
        studies = studies + response.json()['studies']
        print(f'Retreived studies {len(studies)} / {total_count} ({round(100 * len(studies) / total_count)}%)')

        if 'nextPageToken' in response.json():
            parameters['pageToken'] = response.json()['nextPageToken']
        else:
            token = False
            if 'pageToken' in parameters:
                del parameters['pageToken'] # This is necessary to reset the global variable
    
    return studies

# %% [markdown]
# ### Data Collection from [ClinicalTrials.gov](https://clinicaltrials.gov/)
#
# #### Download Field Information
#
# The [ClincalTrials.gov API](https://clinicaltrials.gov/data-api/api) provides an endpoint with database field value information and metadata. This proved to be helpful in understanding and working with the dataset. Data were saved using pickle object serialization and bzip2 compression for further analysis.

# %%
# Download API field information
field_info = requests.get('https://clinicaltrials.gov/api/v2/stats/field/values')
field_info.raise_for_status()
field_info = pd.json_normalize(field_info.json())

# Pickle field info
field_info.to_pickle(data_path + 'field_info.pkl.bz2', compression='bz2')

# %% [markdown]
# #### Download Study Data
#
# Initial project work excluded studies based on `StartDate`, `CompletionDate`, and `Phase`. However, exploratory analysis showed that this had the unintended consequence of excluding all studies with Expanded Access statuses, such as 'Approved for marketing'. In order to keep these studies for exploratory analysis, the inclusion criteria were broadened to rely soley on `OverallStatus` for inclusion/exclusion.

# %%
# Parameters to query '/studies' endpoint
api_server = 'https://clinicaltrials.gov/api/v2'
endpoint = '/studies'
url = api_server + endpoint

# Load list of in scope fields
with open(project_path + 'inscope_fields.txt') as file:
    fields = file.read().splitlines()
print(f'No. fields selected: {len(fields)}')

## Original parameters
# filter_advanced = ['AREA[StartDate]NOT MISSING',
#                    f'AND AREA[CompletionDate]RANGE[MIN, {date.today()}]',
#                    'AND AREA[Phase]NOT (NA OR MISSING)']

# params = {'format': 'json',
#           'fields': ','.join(fields),
#           'filter.overallStatus': 'COMPLETED,SUSPENDED,TERMINATED,WITHDRAWN,AVAILABLE,NO_LONGER_AVAILABLE,TEMPORARILY_NOT_AVAILABLE,APPROVED_FOR_MARKETING,UNKNOWN',
#           'filter.advanced': ' '.join(filter_advanced),
#           'pageSize': 1000}

# Revised parameters
params = {'format': 'json',
          'fields': ','.join(fields),
          'filter.overallStatus': 'COMPLETED,SUSPENDED,TERMINATED,WITHDRAWN,AVAILABLE,NO_LONGER_AVAILABLE,TEMPORARILY_NOT_AVAILABLE,APPROVED_FOR_MARKETING,UNKNOWN',
          'pageSize': 1000}
# Out:
# No. fields selected: 115

# %%
study_count = count_studies(url, params)
print(f'Count of studies in scope: {study_count}')
# Out:
# Count of studies in scope: 383135

# %%
# Retrieve studies
studies = request_all_studies(url, parameters=params)
# Out:
# Retreived studies 1000 / 383135 (0%)
# Retreived studies 2000 / 383135 (1%)
# Retreived studies 3000 / 383135 (1%)
# Retreived studies 4000 / 383135 (1%)
# Retreived studies 5000 / 383135 (1%)
# Retreived studies 6000 / 383135 (2%)
# Retreived studies 7000 / 383135 (2%)
# Retreived studies 8000 / 383135 (2%)
# Retreived studies 9000 / 383135 (2%)
# Retreived studies 10000 / 383135 (3%)
# Retreived studies 11000 / 383135 (3%)
# Retreived studies 12000 / 383135 (3%)
# Retreived studies 13000 / 383135 (3%)
# Retreived studies 14000 / 383135 (4%)
# Retreived studies 15000 / 383135 (4%)
# Retreived studies 16000 / 383135 (4%)
# Retreived studies 17000 / 383135 (4%)
# Retreived studies 18000 / 383135 (5%)
# Retreived studies 19000 / 383135 (5%)
# Retreived studies 20000 / 383135 (5%)
# Retreived studies 21000 / 383135 (5%)
# Retreived studies 22000 / 383135 (6%)
# Retreived studies 23000 / 383135 (6%)
# Retreived studies 24000 / 383135 (6%)
# Retreived studies 25000 / 383135 (7%)
# Retreived studies 26000 / 383135 (7%)
# Retreived studies 27000 / 383135 (7%)
# Retreived studies 28000 / 383135 (7%)
# Retreived studies 29000 / 383135 (8%)
# Retreived studies 30000 / 383135 (8%)
# Retreived studies 31000 / 383135 (8%)
# Retreived studies 32000 / 383135 (8%)
# Retreived studies 33000 / 383135 (9%)
# Retreived studies 34000 / 383135 (9%)
# Retreived studies 35000 / 383135 (9%)
# Retreived studies 36000 / 383135 (9%)
# Retreived studies 37000 / 383135 (10%)
# Retreived studies 38000 / 383135 (10%)
# Retreived studies 39000 / 383135 (10%)
# Retreived studies 40000 / 383135 (10%)
# Retreived studies 41000 / 383135 (11%)
# Retreived studies 42000 / 383135 (11%)
# Retreived studies 43000 / 383135 (11%)
# Retreived studies 44000 / 383135 (11%)
# Retreived studies 45000 / 383135 (12%)
# Retreived studies 46000 / 383135 (12%)
# Retreived studies 47000 / 383135 (12%)
# Retreived studies 48000 / 383135 (13%)
# Retreived studies 49000 / 383135 (13%)
# Retreived studies 50000 / 383135 (13%)
# Retreived studies 51000 / 383135 (13%)
# Retreived studies 52000 / 383135 (14%)
# Retreived studies 53000 / 383135 (14%)
# Retreived studies 54000 / 383135 (14%)
# Retreived studies 55000 / 383135 (14%)
# Retreived studies 56000 / 383135 (15%)
# Retreived studies 57000 / 383135 (15%)
# Retreived studies 58000 / 383135 (15%)
# Retreived studies 59000 / 383135 (15%)
# Retreived studies 60000 / 383135 (16%)
# Retreived studies 61000 / 383135 (16%)
# Retreived studies 62000 / 383135 (16%)
# Retreived studies 63000 / 383135 (16%)
# Retreived studies 64000 / 383135 (17%)
# Retreived studies 65000 / 383135 (17%)
# Retreived studies 66000 / 383135 (17%)
# Retreived studies 67000 / 383135 (17%)
# Retreived studies 68000 / 383135 (18%)
# Retreived studies 69000 / 383135 (18%)
# Retreived studies 70000 / 383135 (18%)
# Retreived studies 71000 / 383135 (19%)
# Retreived studies 72000 / 383135 (19%)
# Retreived studies 73000 / 383135 (19%)
# Retreived studies 74000 / 383135 (19%)
# Retreived studies 75000 / 383135 (20%)
# Retreived studies 76000 / 383135 (20%)
# Retreived studies 77000 / 383135 (20%)
# Retreived studies 78000 / 383135 (20%)
# Retreived studies 79000 / 383135 (21%)
# Retreived studies 80000 / 383135 (21%)
# Retreived studies 81000 / 383135 (21%)
# Retreived studies 82000 / 383135 (21%)
# Retreived studies 83000 / 383135 (22%)
# Retreived studies 84000 / 383135 (22%)
# Retreived studies 85000 / 383135 (22%)
# Retreived studies 86000 / 383135 (22%)
# Retreived studies 87000 / 383135 (23%)
# Retreived studies 88000 / 383135 (23%)
# Retreived studies 89000 / 383135 (23%)
# Retreived studies 90000 / 383135 (23%)
# Retreived studies 91000 / 383135 (24%)
# Retreived studies 92000 / 383135 (24%)
# Retreived studies 93000 / 383135 (24%)
# Retreived studies 94000 / 383135 (25%)
# Retreived studies 95000 / 383135 (25%)
# Retreived studies 96000 / 383135 (25%)
# Retreived studies 97000 / 383135 (25%)
# Retreived studies 98000 / 383135 (26%)
# Retreived studies 99000 / 383135 (26%)
# Retreived studies 100000 / 383135 (26%)
# Retreived studies 101000 / 383135 (26%)
# Retreived studies 102000 / 383135 (27%)
# Retreived studies 103000 / 383135 (27%)
# Retreived studies 104000 / 383135 (27%)
# Retreived studies 105000 / 383135 (27%)
# Retreived studies 106000 / 383135 (28%)
# Retreived studies 107000 / 383135 (28%)
# Retreived studies 108000 / 383135 (28%)
# Retreived studies 109000 / 383135 (28%)
# Retreived studies 110000 / 383135 (29%)
# Retreived studies 111000 / 383135 (29%)
# Retreived studies 112000 / 383135 (29%)
# Retreived studies 113000 / 383135 (29%)
# Retreived studies 114000 / 383135 (30%)
# Retreived studies 115000 / 383135 (30%)
# Retreived studies 116000 / 383135 (30%)
# Retreived studies 117000 / 383135 (31%)
# Retreived studies 118000 / 383135 (31%)
# Retreived studies 119000 / 383135 (31%)
# Retreived studies 120000 / 383135 (31%)
# Retreived studies 121000 / 383135 (32%)
# Retreived studies 122000 / 383135 (32%)
# Retreived studies 123000 / 383135 (32%)
# Retreived studies 124000 / 383135 (32%)
# Retreived studies 125000 / 383135 (33%)
# Retreived studies 126000 / 383135 (33%)
# Retreived studies 127000 / 383135 (33%)
# Retreived studies 128000 / 383135 (33%)
# Retreived studies 129000 / 383135 (34%)
# Retreived studies 130000 / 383135 (34%)
# Retreived studies 131000 / 383135 (34%)
# Retreived studies 132000 / 383135 (34%)
# Retreived studies 133000 / 383135 (35%)
# Retreived studies 134000 / 383135 (35%)
# Retreived studies 135000 / 383135 (35%)
# Retreived studies 136000 / 383135 (35%)
# Retreived studies 137000 / 383135 (36%)
# Retreived studies 138000 / 383135 (36%)
# Retreived studies 139000 / 383135 (36%)
# Retreived studies 140000 / 383135 (37%)
# Retreived studies 141000 / 383135 (37%)
# Retreived studies 142000 / 383135 (37%)
# Retreived studies 143000 / 383135 (37%)
# Retreived studies 144000 / 383135 (38%)
# Retreived studies 145000 / 383135 (38%)
# Retreived studies 146000 / 383135 (38%)
# Retreived studies 147000 / 383135 (38%)
# Retreived studies 148000 / 383135 (39%)
# Retreived studies 149000 / 383135 (39%)
# Retreived studies 150000 / 383135 (39%)
# Retreived studies 151000 / 383135 (39%)
# Retreived studies 152000 / 383135 (40%)
# Retreived studies 153000 / 383135 (40%)
# Retreived studies 154000 / 383135 (40%)
# Retreived studies 155000 / 383135 (40%)
# Retreived studies 156000 / 383135 (41%)
# Retreived studies 157000 / 383135 (41%)
# Retreived studies 158000 / 383135 (41%)
# Retreived studies 159000 / 383135 (41%)
# Retreived studies 160000 / 383135 (42%)
# Retreived studies 161000 / 383135 (42%)
# Retreived studies 162000 / 383135 (42%)
# Retreived studies 163000 / 383135 (43%)
# Retreived studies 164000 / 383135 (43%)
# Retreived studies 165000 / 383135 (43%)
# Retreived studies 166000 / 383135 (43%)
# Retreived studies 167000 / 383135 (44%)
# Retreived studies 168000 / 383135 (44%)
# Retreived studies 169000 / 383135 (44%)
# Retreived studies 170000 / 383135 (44%)
# Retreived studies 171000 / 383135 (45%)
# Retreived studies 172000 / 383135 (45%)
# Retreived studies 173000 / 383135 (45%)
# Retreived studies 174000 / 383135 (45%)
# Retreived studies 175000 / 383135 (46%)
# Retreived studies 176000 / 383135 (46%)
# Retreived studies 177000 / 383135 (46%)
# Retreived studies 178000 / 383135 (46%)
# Retreived studies 179000 / 383135 (47%)
# Retreived studies 180000 / 383135 (47%)
# Retreived studies 181000 / 383135 (47%)
# Retreived studies 182000 / 383135 (48%)
# Retreived studies 183000 / 383135 (48%)
# Retreived studies 184000 / 383135 (48%)
# Retreived studies 185000 / 383135 (48%)
# Retreived studies 186000 / 383135 (49%)
# Retreived studies 187000 / 383135 (49%)
# Retreived studies 188000 / 383135 (49%)
# Retreived studies 189000 / 383135 (49%)
# Retreived studies 190000 / 383135 (50%)
# Retreived studies 191000 / 383135 (50%)
# Retreived studies 192000 / 383135 (50%)
# Retreived studies 193000 / 383135 (50%)
# Retreived studies 194000 / 383135 (51%)
# Retreived studies 195000 / 383135 (51%)
# Retreived studies 196000 / 383135 (51%)
# Retreived studies 197000 / 383135 (51%)
# Retreived studies 198000 / 383135 (52%)
# Retreived studies 199000 / 383135 (52%)
# Retreived studies 200000 / 383135 (52%)
# Retreived studies 201000 / 383135 (52%)
# Retreived studies 202000 / 383135 (53%)
# Retreived studies 203000 / 383135 (53%)
# Retreived studies 204000 / 383135 (53%)
# Retreived studies 205000 / 383135 (54%)
# Retreived studies 206000 / 383135 (54%)
# Retreived studies 207000 / 383135 (54%)
# Retreived studies 208000 / 383135 (54%)
# Retreived studies 209000 / 383135 (55%)
# Retreived studies 210000 / 383135 (55%)
# Retreived studies 211000 / 383135 (55%)
# Retreived studies 212000 / 383135 (55%)
# Retreived studies 213000 / 383135 (56%)
# Retreived studies 214000 / 383135 (56%)
# Retreived studies 215000 / 383135 (56%)
# Retreived studies 216000 / 383135 (56%)
# Retreived studies 217000 / 383135 (57%)
# Retreived studies 218000 / 383135 (57%)
# Retreived studies 219000 / 383135 (57%)
# Retreived studies 220000 / 383135 (57%)
# Retreived studies 221000 / 383135 (58%)
# Retreived studies 222000 / 383135 (58%)
# Retreived studies 223000 / 383135 (58%)
# Retreived studies 224000 / 383135 (58%)
# Retreived studies 225000 / 383135 (59%)
# Retreived studies 226000 / 383135 (59%)
# Retreived studies 227000 / 383135 (59%)
# Retreived studies 228000 / 383135 (60%)
# Retreived studies 229000 / 383135 (60%)
# Retreived studies 230000 / 383135 (60%)
# Retreived studies 231000 / 383135 (60%)
# Retreived studies 232000 / 383135 (61%)
# Retreived studies 233000 / 383135 (61%)
# Retreived studies 234000 / 383135 (61%)
# Retreived studies 235000 / 383135 (61%)
# Retreived studies 236000 / 383135 (62%)
# Retreived studies 237000 / 383135 (62%)
# Retreived studies 238000 / 383135 (62%)
# Retreived studies 239000 / 383135 (62%)
# Retreived studies 240000 / 383135 (63%)
# Retreived studies 241000 / 383135 (63%)
# Retreived studies 242000 / 383135 (63%)
# Retreived studies 243000 / 383135 (63%)
# Retreived studies 244000 / 383135 (64%)
# Retreived studies 245000 / 383135 (64%)
# Retreived studies 246000 / 383135 (64%)
# Retreived studies 247000 / 383135 (64%)
# Retreived studies 248000 / 383135 (65%)
# Retreived studies 249000 / 383135 (65%)
# Retreived studies 250000 / 383135 (65%)
# Retreived studies 251000 / 383135 (66%)
# Retreived studies 252000 / 383135 (66%)
# Retreived studies 253000 / 383135 (66%)
# Retreived studies 254000 / 383135 (66%)
# Retreived studies 255000 / 383135 (67%)
# Retreived studies 256000 / 383135 (67%)
# Retreived studies 257000 / 383135 (67%)
# Retreived studies 258000 / 383135 (67%)
# Retreived studies 259000 / 383135 (68%)
# Retreived studies 260000 / 383135 (68%)
# Retreived studies 261000 / 383135 (68%)
# Retreived studies 262000 / 383135 (68%)
# Retreived studies 263000 / 383135 (69%)
# Retreived studies 264000 / 383135 (69%)
# Retreived studies 265000 / 383135 (69%)
# Retreived studies 266000 / 383135 (69%)
# Retreived studies 267000 / 383135 (70%)
# Retreived studies 268000 / 383135 (70%)
# Retreived studies 269000 / 383135 (70%)
# Retreived studies 270000 / 383135 (70%)
# Retreived studies 271000 / 383135 (71%)
# Retreived studies 272000 / 383135 (71%)
# Retreived studies 273000 / 383135 (71%)
# Retreived studies 274000 / 383135 (72%)
# Retreived studies 275000 / 383135 (72%)
# Retreived studies 276000 / 383135 (72%)
# Retreived studies 277000 / 383135 (72%)
# Retreived studies 278000 / 383135 (73%)
# Retreived studies 279000 / 383135 (73%)
# Retreived studies 280000 / 383135 (73%)
# Retreived studies 281000 / 383135 (73%)
# Retreived studies 282000 / 383135 (74%)
# Retreived studies 283000 / 383135 (74%)
# Retreived studies 284000 / 383135 (74%)
# Retreived studies 285000 / 383135 (74%)
# Retreived studies 286000 / 383135 (75%)
# Retreived studies 287000 / 383135 (75%)
# Retreived studies 288000 / 383135 (75%)
# Retreived studies 289000 / 383135 (75%)
# Retreived studies 290000 / 383135 (76%)
# Retreived studies 291000 / 383135 (76%)
# Retreived studies 292000 / 383135 (76%)
# Retreived studies 293000 / 383135 (76%)
# Retreived studies 294000 / 383135 (77%)
# Retreived studies 295000 / 383135 (77%)
# Retreived studies 296000 / 383135 (77%)
# Retreived studies 297000 / 383135 (78%)
# Retreived studies 298000 / 383135 (78%)
# Retreived studies 299000 / 383135 (78%)
# Retreived studies 300000 / 383135 (78%)
# Retreived studies 301000 / 383135 (79%)
# Retreived studies 302000 / 383135 (79%)
# Retreived studies 303000 / 383135 (79%)
# Retreived studies 304000 / 383135 (79%)
# Retreived studies 305000 / 383135 (80%)
# Retreived studies 306000 / 383135 (80%)
# Retreived studies 307000 / 383135 (80%)
# Retreived studies 308000 / 383135 (80%)
# Retreived studies 309000 / 383135 (81%)
# Retreived studies 310000 / 383135 (81%)
# Retreived studies 311000 / 383135 (81%)
# Retreived studies 312000 / 383135 (81%)
# Retreived studies 313000 / 383135 (82%)
# Retreived studies 314000 / 383135 (82%)
# Retreived studies 315000 / 383135 (82%)
# Retreived studies 316000 / 383135 (82%)
# Retreived studies 317000 / 383135 (83%)
# Retreived studies 318000 / 383135 (83%)
# Retreived studies 319000 / 383135 (83%)
# Retreived studies 320000 / 383135 (84%)
# Retreived studies 321000 / 383135 (84%)
# Retreived studies 322000 / 383135 (84%)
# Retreived studies 323000 / 383135 (84%)
# Retreived studies 324000 / 383135 (85%)
# Retreived studies 325000 / 383135 (85%)
# Retreived studies 326000 / 383135 (85%)
# Retreived studies 327000 / 383135 (85%)
# Retreived studies 328000 / 383135 (86%)
# Retreived studies 329000 / 383135 (86%)
# Retreived studies 330000 / 383135 (86%)
# Retreived studies 331000 / 383135 (86%)
# Retreived studies 332000 / 383135 (87%)
# Retreived studies 333000 / 383135 (87%)
# Retreived studies 334000 / 383135 (87%)
# Retreived studies 335000 / 383135 (87%)
# Retreived studies 336000 / 383135 (88%)
# Retreived studies 337000 / 383135 (88%)
# Retreived studies 338000 / 383135 (88%)
# Retreived studies 339000 / 383135 (88%)
# Retreived studies 340000 / 383135 (89%)
# Retreived studies 341000 / 383135 (89%)
# Retreived studies 342000 / 383135 (89%)
# Retreived studies 343000 / 383135 (90%)
# Retreived studies 344000 / 383135 (90%)
# Retreived studies 345000 / 383135 (90%)
# Retreived studies 346000 / 383135 (90%)
# Retreived studies 347000 / 383135 (91%)
# Retreived studies 348000 / 383135 (91%)
# Retreived studies 349000 / 383135 (91%)
# Retreived studies 350000 / 383135 (91%)
# Retreived studies 351000 / 383135 (92%)
# Retreived studies 352000 / 383135 (92%)
# Retreived studies 353000 / 383135 (92%)
# Retreived studies 354000 / 383135 (92%)
# Retreived studies 355000 / 383135 (93%)
# Retreived studies 356000 / 383135 (93%)
# Retreived studies 357000 / 383135 (93%)
# Retreived studies 358000 / 383135 (93%)
# Retreived studies 359000 / 383135 (94%)
# Retreived studies 360000 / 383135 (94%)
# Retreived studies 361000 / 383135 (94%)
# Retreived studies 362000 / 383135 (94%)
# Retreived studies 363000 / 383135 (95%)
# Retreived studies 364000 / 383135 (95%)
# Retreived studies 365000 / 383135 (95%)
# Retreived studies 366000 / 383135 (96%)
# Retreived studies 367000 / 383135 (96%)
# Retreived studies 368000 / 383135 (96%)
# Retreived studies 369000 / 383135 (96%)
# Retreived studies 370000 / 383135 (97%)
# Retreived studies 371000 / 383135 (97%)
# Retreived studies 372000 / 383135 (97%)
# Retreived studies 373000 / 383135 (97%)
# Retreived studies 374000 / 383135 (98%)
# Retreived studies 375000 / 383135 (98%)
# Retreived studies 376000 / 383135 (98%)
# Retreived studies 377000 / 383135 (98%)
# Retreived studies 378000 / 383135 (99%)
# Retreived studies 379000 / 383135 (99%)
# Retreived studies 380000 / 383135 (99%)
# Retreived studies 381000 / 383135 (99%)
# Retreived studies 382000 / 383135 (100%)
# Retreived studies 383000 / 383135 (100%)
# Retreived studies 383135 / 383135 (100%)

# %% [markdown]
# #### Save Study Data to File

# %%
# Pickle the studies data
filename = data_path + datetime.now().strftime('%Y-%m-%dT%H%M%S') + '_studies_json.pkl.bz2'

with bz2.BZ2File(filename, 'w') as file:
    pickle.dump(studies, file)

print(f'Saved {study_count} study records to {filename}')
# Out:
# Saved 383135 study records to ../data/2024-05-22T142524_studies_json.pkl.bz2
